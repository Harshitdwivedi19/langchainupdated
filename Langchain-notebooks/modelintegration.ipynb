# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model= init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(output_version=None, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000002972554CE50>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000029726FF4790>, root_client=<openai.OpenAI object at 0x00000297255ED870>, root_async_client=<openai.AsyncOpenAI object at 0x000002972690E0E0>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)

# %%
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model1 = init_chat_model("google_genai:gemini-2.5-flash-lite")
model1
response = model1.invoke("Why do parrots talk?")

# %%
response.content
# Out:
# 'Parrots talk for a fascinating combination of reasons, primarily rooted in their **social nature, intelligence, and evolutionary adaptations.** It\'s not just about mimicking sounds; it\'s a complex behavior with several underlying motivations:\n\n**1. Social Bonding and Communication:**\n\n*   **Flock Calls:** In the wild, parrots are highly social creatures that live in flocks. They use a variety of vocalizations to stay in contact with their group, warn of danger, locate food, and maintain social cohesion. Talking, or more accurately, vocal mimicry, can be an extension of this in captivity.\n*   **Gaining Attention and Affection:** In a human home, a parrot sees its owners as its flock. By mimicking sounds, especially human speech, they are trying to get your attention, engage with you, and solicit interaction. It\'s a way for them to say, "Hey, I\'m here! Notice me!"\n*   **Building Relationships:** Mimicking sounds, including words and phrases, can help parrots integrate into their human flock. When they learn words associated with positive interactions, like "hello" or "good bird," they reinforce those connections.\n\n**2. Intelligence and Cognitive Abilities:**\n\n*   **Learning and Problem-Solving:** Parrots are incredibly intelligent birds. They have large brains and are capable of learning, remembering, and even understanding the context of certain sounds and words.\n*   **Curiosity and Exploration:** They are naturally curious about their environment and the sounds they hear. Mimicking is a way for them to explore and understand these sounds.\n*   **Cognitive Stimulation:** Talking provides mental stimulation for parrots. It keeps their minds active and prevents boredom, which can lead to behavioral problems.\n\n**3. Evolutionary Advantage (in the wild):**\n\n*   **Mimicry for Survival:** While not directly for human speech, the ability to mimic sounds in the wild can be an evolutionary advantage. It could help them:\n    *   **Blend in:** Mimicking the sounds of predators or other birds might help them avoid detection.\n    *   **Attract Mates:** Some birds use complex vocalizations to attract mates.\n    *   **Communicate in Complex Environments:** In dense forests, vocalizations are crucial for communication.\n\n**4. Innate Vocal Ability:**\n\n*   **Syrinx Structure:** Parrots have a specialized vocal organ called a syrinx, which is more complex than that of many other birds. This allows them to produce a wide range of sounds, including those that resemble human speech.\n*   **Motivation to Vocalize:** Parrots are inherently vocal creatures. They enjoy making noise and expressing themselves, and vocal mimicry is a particularly fascinating outlet for this.\n\n**Important Considerations:**\n\n*   **Not All Parrots Talk:** While many species of parrots are known for their talking ability, not all individuals within a species will talk, nor will all species be equally adept at it. African Greys, Amazons, and some cockatoos are particularly renowned for their talking skills.\n*   **Understanding vs. Mimicry:** It\'s a common misconception that parrots fully understand the meaning of every word they say. While some highly intelligent parrots can learn to associate words with objects or actions, much of their "talking" is sophisticated mimicry. However, they can learn to use words in appropriate contexts, which is a remarkable feat.\n*   **Individual Differences:** Just like humans, some parrots are more talkative and eager to learn than others. Personality, environment, and the owner\'s efforts all play a role.\n\nIn essence, parrots talk because they are intelligent, social beings who use their impressive vocal abilities to connect with their flock, explore their world, and express themselves. Their ability to mimic human speech is a testament to their cognitive prowess and their desire to be an active part of their human family.'

# %%
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model2 = init_chat_model("groq:openai/gpt-oss-120b")
response = model2.invoke("why do parrots talk?")
response.content
# Out:
# 'Parrots don’t *actually* talk the way humans do—they’re amazing mimics. Their “talking” comes from a combination of biology, social needs, and the environments they live in.\n\n### 1. **Vocal anatomy that’s built for imitation**\n- **Syrinx:** Birds produce sound with a organ called the syrinx, located at the base of the trachea. In parrots the syrinx is especially flexible, giving them a wide range of pitches and tones.\n- **Muscle control:** Parrots have more muscular control over the syrinx than most birds, allowing them to shape sounds with fine precision—much like a human’s vocal cords plus a built‑in sound‑board.\n\n### 2. **A highly social brain**\n- **Flock communication:** In the wild, parrots live in noisy, tight‑knit flocks. They constantly call to keep track of one another, signal food sources, warn of predators, and reinforce social bonds.\n- **Learning by listening:** Young parrots learn the “dialects” of their flock by listening and copying. This same learning mechanism is triggered when they hear human speech.\n\n### 3. **Intelligence and curiosity**\n- Parrots are among the most cognitively advanced birds (some species rank near primates on problem‑solving tests). Their curiosity drives them to explore new sounds, and they quickly notice that certain noises (like a human saying “hello”) get a reaction—attention, treats, or affection.\n\n### 4. **Positive reinforcement from humans**\n- When a pet parrot mimics a word and the owner responds with excitement, laughter, or a treat, the bird gets a reward. Over time it learns that reproducing that sound is a reliable way to get something desirable.\n\n### 5. **Why some species are better talkers**\n| Species | Typical Talking Ability | Why they excel |\n|--------|------------------------|----------------|\n| African Grey (Psittacus erithacus) | Very clear, extensive vocab (hundreds of words) | Large brain relative to body, strong social bonds, long lifespan |\n| Amazon parrots (e.g., Yellow‑naped) | Loud, expressive speech, good at mimicry | Energetic, vocal nature, love of interaction |\n| Budgerigars (budgies) | Small but clear words, especially “hello” | Small size → high-pitched syrinx, often kept in pairs (social) |\n| Cockatiels | Limited vocab, good at whistles & phrases | Simpler brain structure, but still enjoy social interaction |\n\n### 6. **Limits of “talking”**\n- **No understanding of grammar:** Most parrots associate a word with a context (e.g., “food” when they’re hungry) rather than grasping syntax.\n- **Vocal range:** They can’t produce certain consonants (like “th” or “r”) perfectly, so the sounds are often approximations.\n- **Individual variation:** Not every parrot will talk; personality, age, and the amount of human interaction all play roles.\n\n### Quick Takeaway\nParrots talk because they’re built to copy sounds, they’re socially driven to communicate, and they learn that mimicking human speech gets them attention, food, or companionship. Their impressive vocal anatomy and high intelligence make them the ultimate “audio chameleons” of the animal kingdom.'
